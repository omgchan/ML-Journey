# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/annual-number-of-deaths-by-cause.csv')

# %%
df.shape
# Out:
# (7273, 36)

# %%
df.head()
# Out:
#         Entity Code  Year Number of executions (Amnesty International)  \
# 0  Afghanistan  AFG  2007                                           15
# 1  Afghanistan  AFG  2008                                           17
# 2  Afghanistan  AFG  2009                                            0
# 3  Afghanistan  AFG  2011                                            2
# 4  Afghanistan  AFG  2012                                           14
#
#    Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# 0                                             2933.0
# 1                                             2731.0
# 2                                             2460.0
# 3                                             2327.0
# 4                                             2254.0
#
#    Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)  \
# 0                                             1402.0
# 1                                             1424.0
# ...

# %%
df.sample(5)
# Out:
#               Entity Code  Year Number of executions (Amnesty International)  \
# 5955       Sri Lanka  LKA  1990                                          NaN
# 6089        Suriname  SUR  2007                                          NaN
# 820         Botswana  BWA  2005                                          NaN
# 1805  Eastern Europe  NaN  2008                                          NaN
# 6577          Tuvalu  TUV  2015                                          NaN
#
#       Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# 5955                                              587.0
# 6089                                                8.0
# 820                                               149.0
# 1805                                                NaN
# 6577                                                0.0
#
#       Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)  \
# 5955                                             1423.0
# ...

# %%
df.tail()
# Out:
#         Entity Code  Year Number of executions (Amnesty International)  \
# 7268  Zimbabwe  ZWE  2015                                          NaN
# 7269  Zimbabwe  ZWE  2016                                          NaN
# 7270  Zimbabwe  ZWE  2017                                          NaN
# 7271  Zimbabwe  ZWE  2018                                          NaN
# 7272  Zimbabwe  ZWE  2019                                          NaN
#
#       Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# 7268                                             1439.0
# 7269                                             1457.0
# 7270                                             1460.0
# 7271                                             1450.0
# 7272                                             1450.0
#
#       Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)  \
# 7268                                              754.0
# ...

# %%
df.isnull().sum()
# Out:
# Entity                                                                                         0
# Code                                                                                        1067
# Year                                                                                           0
# Number of executions (Amnesty International)                                                7006
# Deaths - Meningitis - Sex: Both - Age: All Ages (Number)                                     433
# Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)        433
# Deaths - Parkinson's disease - Sex: Both - Age: All Ages (Number)                            433
# Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)                       433
# Deaths - Malaria - Sex: Both - Age: All Ages (Number)                                        433
# Deaths - Drowning - Sex: Both - Age: All Ages (Number)                                       433
# ...

# %%
df.describe()
# Out:
#               Year  Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# count  7273.000000                                        6840.000000
# mean   2004.425134                                        8213.149415
# std       8.623572                                       34982.934459
# min    1990.000000                                           0.000000
# 25%    1997.000000                                          19.000000
# 50%    2004.000000                                         150.500000
# 75%    2012.000000                                        1622.250000
# max    2019.000000                                      432524.000000
#
#        Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)  \
# count                                       6.840000e+03
# mean                                        2.736319e+04
# std                                         1.113146e+05
# min                                         0.000000e+00
# ...

# %%
nepal= df[df["Entity"] == "Nepal"]
nepal
# Out:
#      Entity Code  Year Number of executions (Amnesty International)  \
# 4222  Nepal  NPL  1990                                          NaN
# 4223  Nepal  NPL  1991                                          NaN
# 4224  Nepal  NPL  1992                                          NaN
# 4225  Nepal  NPL  1993                                          NaN
# 4226  Nepal  NPL  1994                                          NaN
# 4227  Nepal  NPL  1995                                          NaN
# 4228  Nepal  NPL  1996                                          NaN
# 4229  Nepal  NPL  1997                                          NaN
# 4230  Nepal  NPL  1998                                          NaN
# 4231  Nepal  NPL  1999                                          NaN
# 4232  Nepal  NPL  2000                                          NaN
# 4233  Nepal  NPL  2001                                          NaN
# 4234  Nepal  NPL  2002                                          NaN
# ...

# %%
nepal.drop(columns=["Code", "Number of executions (Amnesty International)"],  inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18572\2354635171.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nepal.drop(columns=["Code", "Number of executions (Amnesty International)"],  inplace=True)

# %%
nepal
# Out:
#      Entity  Year  Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# 4222  Nepal  1990                                             2367.0
# 4223  Nepal  1991                                             2234.0
# 4224  Nepal  1992                                             2115.0
# 4225  Nepal  1993                                             2014.0
# 4226  Nepal  1994                                             1918.0
# 4227  Nepal  1995                                             1830.0
# 4228  Nepal  1996                                             1744.0
# 4229  Nepal  1997                                             1663.0
# 4230  Nepal  1998                                             1584.0
# 4231  Nepal  1999                                             1504.0
# 4232  Nepal  2000                                             1425.0
# 4233  Nepal  2001                                             1342.0
# ...

# %%
nepal.nunique()
# Out:
# Entity                                                                                       1
# Year                                                                                        30
# Deaths - Meningitis - Sex: Both - Age: All Ages (Number)                                    30
# Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)       30
# Deaths - Parkinson's disease - Sex: Both - Age: All Ages (Number)                           30
# Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)                      30
# Deaths - Malaria - Sex: Both - Age: All Ages (Number)                                       25
# Deaths - Drowning - Sex: Both - Age: All Ages (Number)                                      30
# Deaths - Interpersonal violence - Sex: Both - Age: All Ages (Number)                        28
# Deaths - Maternal disorders - Sex: Both - Age: All Ages (Number)                            30
# ...

# %%
nepal.isnull().sum()
# Out:
# Entity                                                                                      0
# Year                                                                                        0
# Deaths - Meningitis - Sex: Both - Age: All Ages (Number)                                    0
# Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)       0
# Deaths - Parkinson's disease - Sex: Both - Age: All Ages (Number)                           0
# Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)                      0
# Deaths - Malaria - Sex: Both - Age: All Ages (Number)                                       0
# Deaths - Drowning - Sex: Both - Age: All Ages (Number)                                      0
# Deaths - Interpersonal violence - Sex: Both - Age: All Ages (Number)                        0
# Deaths - Maternal disorders - Sex: Both - Age: All Ages (Number)                            0
# ...

# %%
nepal.isna().sum()
# Out:
# Entity                                                                                      0
# Year                                                                                        0
# Deaths - Meningitis - Sex: Both - Age: All Ages (Number)                                    0
# Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)       0
# Deaths - Parkinson's disease - Sex: Both - Age: All Ages (Number)                           0
# Deaths - Nutritional deficiencies - Sex: Both - Age: All Ages (Number)                      0
# Deaths - Malaria - Sex: Both - Age: All Ages (Number)                                       0
# Deaths - Drowning - Sex: Both - Age: All Ages (Number)                                      0
# Deaths - Interpersonal violence - Sex: Both - Age: All Ages (Number)                        0
# Deaths - Maternal disorders - Sex: Both - Age: All Ages (Number)                            0
# ...

# %%
nepal['Terrorism (deaths)'] = nepal['Terrorism (deaths)'].fillna(0)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18572\1246876382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nepal['Terrorism (deaths)'] = nepal['Terrorism (deaths)'].fillna(0)

# %%
nepal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 nepal
#
# NameError: name 'nepal' is not defined

# %%
plt.plot(nepal['Year'], nepal['Terrorism (deaths)'])
plt.xlabel('Year')
plt.ylabel('Number of Terrorism Deaths')
plt.title('Terrorism-related Deaths in Nepal Over Time')
plt.show()
